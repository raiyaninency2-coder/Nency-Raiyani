# %%
import numpy as np

# %% [markdown]
# # for data_type {array_name.dtye}

# %%
arr = np.array([1,2,3,4,5,6])
print(arr.dtype)
# Out:
# int64

# %%
arr1 = np.array(["nency"])
arr1.dtype
# Out:
# dtype('<U5')

# %% [markdown]
# # convert into other datatypes

# %%
arr2 = np.array([1,2,3,4],dtype="f")
arr2
# Out:
# array([1., 2., 3., 4.], dtype=float32)

# %%
x = np.float16(arr2)
x.dtype
# Out:
# dtype('float16')
